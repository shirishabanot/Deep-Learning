# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer
from keras.models import Sequential
import keras
from keras.layers import Dense, InputLayer

# %%
#pip install tensorflow==2.12.0

# %%
data=pd.read_csv(r"C:\Users\hp\Downloads\IPL project\final_ipl_data1.csv")

# %%
data
# Out:
#                        BattingTeam            BowlingTeam  runs_left  \
# 0                   Gujarat Titans       Rajasthan Royals      131.0
# 1                   Gujarat Titans       Rajasthan Royals      131.0
# 2                   Gujarat Titans       Rajasthan Royals      130.0
# 3                   Gujarat Titans       Rajasthan Royals      130.0
# 4                   Gujarat Titans       Rajasthan Royals      130.0
# ...                            ...                    ...        ...
# 85934  Royal Challengers Bangalore  Kolkata Knight Riders      143.0
# 85935  Royal Challengers Bangalore  Kolkata Knight Riders      142.0
# 85936  Royal Challengers Bangalore  Kolkata Knight Riders      142.0
# 85937  Royal Challengers Bangalore  Kolkata Knight Riders      141.0
# 85938  Royal Challengers Bangalore  Kolkata Knight Riders      141.0
#
#        balls_left  wickets_remaining  target   crr    rrr  results
# 0             119                 10   131.0  0.00   6.61        1
# 1             118                 10   131.0  0.00   6.66        1
# 2             117                 10   131.0  2.00   6.67        1
# 3             116                 10   131.0  1.50   6.72        1
# 4             115                 10   131.0  1.20   6.78        1
# ...           ...                ...     ...   ...    ...      ...
# 85934          31                  1   223.0  5.39  27.68        0
# 85935          30                  1   223.0  5.40  28.40        0
# 85936          29                  1   223.0  5.34  29.38        0
# 85937          29                  1   223.0  5.41  29.17        0
# 85938          28                  0   223.0  5.35  30.21        0
#
# [85939 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85939 entries, 0 to 85938
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BattingTeam        85939 non-null  object
#  1   BowlingTeam        85939 non-null  object
#  2   runs_left          85939 non-null  float64
#  3   balls_left         85939 non-null  int64
#  4   wickets_remaining  85939 non-null  int64
#  5   target             85939 non-null  float64
#  6   crr                85939 non-null  float64
#  7   rrr                85939 non-null  float64
#  8   results            85939 non-null  int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 5.9+ MB

# %%
#Extracting feature variables and class variables
fv=data.iloc[:,:-1]
cv=data.iloc[:,-1]

# %%
# Splitting tha data to train and test splits
x_train,x_test,y_train,y_test = train_test_split(fv,cv,test_size=0.2, random_state=42, stratify=cv)

# %%
#Dividing te dataset based on the type if the variables
numerical_data=x_train.select_dtypes(include=["int64","float64"])
cat_data=x_train.select_dtypes(include=["object"])

# %%
#Pipeline to impute and scale numerical columns
num_p=Pipeline([("imputing_n",SimpleImputer()),("scaling",StandardScaler())])
#Pipeline to impute and Encode nominal columns
cp=Pipeline([("imputing_c",SimpleImputer(strategy="most_frequent")),("Encoder",OneHotEncoder())])

# %%
#Pipeline for column transformation to apply for different types of data
ct=ColumnTransformer([("nominal",cp,cat_data.columns),("numerical",num_p,numerical_data.columns)],remainder="passthrough")

# %%
ct
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('nominal',
#                                  Pipeline(steps=[('imputing_c',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('Encoder', OneHotEncoder())]),
#                                  Index(['BattingTeam', 'BowlingTeam'], dtype='object')),
#                                 ('numerical',
#                                  Pipeline(steps=[('imputing_n',
#                                                   SimpleImputer()),
#                                                  ('scaling',
#                                                   StandardScaler())]),
#                                  Index(['runs_left', 'balls_left', 'wickets_remaining', 'target', 'crr', 'rrr'], dtype='object'))])

# %%
x_test.shape
# Out:
# (17188, 8)

# %%
x_train_pp=ct.fit_transform(x_train)
x_test_pp=ct.transform(x_test)

# %%
print(x_train_pp.shape)
print(x_test_pp.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (68751, 24)
# (17188, 24)
# (68751,)
# (17188,)

# %%
from keras.utils import to_categorical

# Assuming y_train is a 1D array containing class labels
y_train_encoded = to_categorical(y_train,num_classes=2)

# Assuming y_test is a 1D array containing class labels
y_test_encoded = to_categorical(y_test,num_classes=2)

# %%
from keras.models import Model
from keras.layers import Input, Dense

def create_ann_model(input_shape):
    # Input layer
    inputs = Input(shape=(input_shape,))
    
    # Dense hidden layers
    dense1 = Dense(64, activation='relu')(inputs)
    dense2 = Dense(32, activation='relu')(dense1)
    
    # Output layers for batting team and bowling team
    output_batting = Dense(1, activation='sigmoid', name='output_batting')(dense2)
    output_bowling = Dense(1, activation='sigmoid', name='output_bowling')(dense2)
    
    # Define the model with multiple outputs
    model = Model(inputs=inputs, outputs=[output_batting, output_bowling])
    
    # Compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# Example usage:
input_shape = x_train_pp.shape[1]
ann_model = create_ann_model(input_shape)

# %%
input_shape = x_train_pp.shape[1]
model=Sequential()
model.add(InputLayer(input_shape=(input_shape,)))
model.add(Dense(5,activation="relu",use_bias=True))
model.add(Dense(4,activation="relu",use_bias=True))
model.add(Dense(2,activation="softmax",use_bias=True))
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
model.compile(optimizer='adam',loss="binary_crossentropy",metrics=["accuracy"])

# %%
from keras.callbacks import ModelCheckpoint

# Define the filepath where you want to save the best model weights
checkpoint_filepath = r"C:\Users\hp\Downloads\IPL project\best_ipl_model_weights.keras"

# Create a ModelCheckpoint callback
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',  # or 'val_accuracy' depending on your preference
    save_best_only=True,
    mode='min'  # or 'max' if monitoring accuracy
)

# Train the model with the ModelCheckpoint callback
history = model.fit(
    x_train_pp, y_train_encoded,
    epochs=50,
    batch_size=100,
    validation_data=(x_test_pp, y_test_encoded),
    callbacks=[checkpoint_callback]  # Pass the checkpoint callback here
)
# Out:
# Epoch 1/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6631 - loss: 0.6303 - val_accuracy: 0.7970 - val_loss: 0.4825
# Epoch 2/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7988 - loss: 0.4694 - val_accuracy: 0.8037 - val_loss: 0.4461
# Epoch 3/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8087 - loss: 0.4370 - val_accuracy: 0.8081 - val_loss: 0.4308
# Epoch 4/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8125 - loss: 0.4226 - val_accuracy: 0.8120 - val_loss: 0.4219
# Epoch 5/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8171 - loss: 0.4123 - val_accuracy: 0.8134 - val_loss: 0.4144
# Epoch 6/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8146 - loss: 0.4088 - val_accuracy: 0.8136 - val_loss: 0.4091
# Epoch 7/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8162 - loss: 0.3994 - val_accuracy: 0.8153 - val_loss: 0.4040
# Epoch 8/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8175 - loss: 0.3958 - val_accuracy: 0.8174 - val_loss: 0.3998
# Epoch 9/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8187 - loss: 0.3927 - val_accuracy: 0.8190 - val_loss: 0.3965
# Epoch 10/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8228 - loss: 0.3884 - val_accuracy: 0.8202 - val_loss: 0.3930
# Epoch 11/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8261 - loss: 0.3812 - val_accuracy: 0.8223 - val_loss: 0.3901
# Epoch 12/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8269 - loss: 0.3799 - val_accuracy: 0.8231 - val_loss: 0.3883
# Epoch 13/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8299 - loss: 0.3764 - val_accuracy: 0.8266 - val_loss: 0.3859
# Epoch 14/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8280 - loss: 0.3795 - val_accuracy: 0.8266 - val_loss: 0.3839
# Epoch 15/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8318 - loss: 0.3721 - val_accuracy: 0.8267 - val_loss: 0.3827
# Epoch 16/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8325 - loss: 0.3722 - val_accuracy: 0.8280 - val_loss: 0.3811
# Epoch 17/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8336 - loss: 0.3694 - val_accuracy: 0.8276 - val_loss: 0.3797
# Epoch 18/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8323 - loss: 0.3712 - val_accuracy: 0.8288 - val_loss: 0.3788
# Epoch 19/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8334 - loss: 0.3694 - val_accuracy: 0.8288 - val_loss: 0.3777
# Epoch 20/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8328 - loss: 0.3705 - val_accuracy: 0.8283 - val_loss: 0.3763
# Epoch 21/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8340 - loss: 0.3681 - val_accuracy: 0.8301 - val_loss: 0.3750
# Epoch 22/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8332 - loss: 0.3665 - val_accuracy: 0.8302 - val_loss: 0.3734
# Epoch 23/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8359 - loss: 0.3665 - val_accuracy: 0.8297 - val_loss: 0.3728
# Epoch 24/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8358 - loss: 0.3626 - val_accuracy: 0.8309 - val_loss: 0.3704
# Epoch 25/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8373 - loss: 0.3638 - val_accuracy: 0.8314 - val_loss: 0.3695
# Epoch 26/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8359 - loss: 0.3626 - val_accuracy: 0.8338 - val_loss: 0.3682
# Epoch 27/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8382 - loss: 0.3577 - val_accuracy: 0.8318 - val_loss: 0.3674
# Epoch 28/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8372 - loss: 0.3570 - val_accuracy: 0.8349 - val_loss: 0.3652
# Epoch 29/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8382 - loss: 0.3557 - val_accuracy: 0.8336 - val_loss: 0.3650
# Epoch 30/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8388 - loss: 0.3561 - val_accuracy: 0.8343 - val_loss: 0.3639
# Epoch 31/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8407 - loss: 0.3516 - val_accuracy: 0.8333 - val_loss: 0.3633
# Epoch 32/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8380 - loss: 0.3525 - val_accuracy: 0.8344 - val_loss: 0.3626
# Epoch 33/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8357 - loss: 0.3553 - val_accuracy: 0.8351 - val_loss: 0.3617
# Epoch 34/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8388 - loss: 0.3519 - val_accuracy: 0.8351 - val_loss: 0.3610
# Epoch 35/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8391 - loss: 0.3513 - val_accuracy: 0.8348 - val_loss: 0.3600
# Epoch 36/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8394 - loss: 0.3514 - val_accuracy: 0.8360 - val_loss: 0.3590
# Epoch 37/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8402 - loss: 0.3502 - val_accuracy: 0.8372 - val_loss: 0.3581
# Epoch 38/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8407 - loss: 0.3475 - val_accuracy: 0.8363 - val_loss: 0.3571
# Epoch 39/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8402 - loss: 0.3472 - val_accuracy: 0.8363 - val_loss: 0.3568
# Epoch 40/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8413 - loss: 0.3442 - val_accuracy: 0.8366 - val_loss: 0.3559
# Epoch 41/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8431 - loss: 0.3443 - val_accuracy: 0.8354 - val_loss: 0.3550
# Epoch 42/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8391 - loss: 0.3463 - val_accuracy: 0.8358 - val_loss: 0.3538
# Epoch 43/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8424 - loss: 0.3443 - val_accuracy: 0.8365 - val_loss: 0.3538
# Epoch 44/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8443 - loss: 0.3419 - val_accuracy: 0.8373 - val_loss: 0.3533
# Epoch 45/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8434 - loss: 0.3427 - val_accuracy: 0.8375 - val_loss: 0.3532
# Epoch 46/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8413 - loss: 0.3465 - val_accuracy: 0.8364 - val_loss: 0.3530
# Epoch 47/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8425 - loss: 0.3423 - val_accuracy: 0.8373 - val_loss: 0.3517
# Epoch 48/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8436 - loss: 0.3444 - val_accuracy: 0.8374 - val_loss: 0.3526
# Epoch 49/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8426 - loss: 0.3435 - val_accuracy: 0.8382 - val_loss: 0.3517
# Epoch 50/50
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8426 - loss: 0.3439 - val_accuracy: 0.8387 - val_loss: 0.3513

# %%
from keras.models import load_model

# Load the model architecture
best_model = load_model(r"C:\Users\hp\Downloads\IPL project\best_ipl_model_weights.keras")

# %%
new_data_point = x_test_pp[0].reshape(1, -1)
probability= best_model.predict(new_data_point)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step

# %%
np.argmax(best_model.predict(new_data_point))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 0

# %%
probability
# Out:
# array([[9.9927694e-01, 7.2308898e-04]], dtype=float32)

# %%
predictions = np.array([[9.999924e-01, 7.673831e-06]])

# Convert probabilities to percentages
probabilities_percentage = predictions * 100
probabilities_percentage
# Out:
# array([[9.999924e+01, 7.673831e-04]])

# %%
input_data = pd.DataFrame({
    'BattingTeam': ["Chennai Super Kings"],
    'BowlingTeam': ["Delhi Capitals"],
    'runs_left': [10],
    'balls_left': [20],
    'wickets_remaining': [5],
    'target': [200],
    'crr': [4.6],
    'rrr': [5.6]
})

# Transform the input data using the ColumnTransformer
x = ct.transform(input_data)

# %%
new_data_point = x.reshape(1, -1)
probabilities = best_model.predict(new_data_point)
print(probabilities)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.20004578 0.79995424]]

# %%
np.argmax(best_model.predict(new_data_point))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1

# %%
probabilities[0][0]*100
# Out:
# 20.004577934741974
